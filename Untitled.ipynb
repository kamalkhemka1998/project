# %%
import pandas as pd
from pymongo import MongoClient
import pprint as pp
import numpy as np
import itertools
import json
myclient = MongoClient('88.99.143.82',47118)
db = myclient['dhi_analytics']

# %%
db.authenticate('analytics','pPM8FUJflenw')
# Out:
# True

# %%
def hodDetails(facultyId, academicYear, termNumber, degreeId):
    hodDepartment = [x for x in db.dhi_user.aggregate([
        {"$match": {
            "employeeGivenId": facultyId,
            # "academicYear": academicYear, 
            "degreeId": degreeId}},
        {"$unwind": "$handlingDegreeAndDepartments"},
        {"$unwind": "$handlingDegreeAndDepartments.handlingDepartments"},

        {"$project": {
            "_id": 0,
            "deptName": "$handlingDegreeAndDepartments.handlingDepartments.deptName",
            "deptId": "$handlingDegreeAndDepartments.handlingDepartments.deptId"}}
    ])]
    if hodDepartment !=[]:
        return (hodSubject(academicYear, termNumber,
                       hodDepartment[0]["deptId"]))

# %%
def hodSubject(academicYear, termNumber, department):
    termNumber = list(termNumber.split(","))
    # pprint(termNumber)
    course = [subjects for subjects in db.dhi_lesson_plan.aggregate([
        {'$match': {
            'academicYear': academicYear,
            'departments.termNumber': {'$in': termNumber},
            # 'degreeId': degreeId,
            'departments.deptId': department
        }
        },
        {"$unwind": "$faculties"},
        {"$unwind": "$departments"},
        {'$project': {
            '_id': 0,

            'facultyId': '$faculties.facultyId',

        }}

    ])]
    facultylist = []
    for x in course:
        if "facultyId" in x:
            if x["facultyId"] not in facultylist:
                facultylist.append(x["facultyId"])
    finalanswer = []
   
    final = get_overall_attainment_data(facultylist,termNumber,academicYear)
    return final

# %%
def get_attainment_details(x):
    attaiment_data = db.dhi_generic_attainment_data.aggregate([
    {'$unwind':'$courseDetails'},
    {'$unwind':'$faculties'},
    {'$match':{
        'termNumber':x['termNumber'],
        'section':x['section'],
        'courseDetails.courseCode':x['courseCode'],
        'faculties.facultyId':x['facultyId'],
        'academicYear':x['year']
      }    
    },
        
    {'$unwind':'$courseOutcomeDetailsForAttainment'},
    {
      '$project':
        {
        '_id':0,
        'coNumber':'$courseOutcomeDetailsForAttainment.coNumber',
        'coTitle':'$courseOutcomeDetailsForAttainment.coTitle',
        'termNumber':'$termNumber',
        'section':'$section',
        'courseCode':'$courseDetails.courseCode',
        'year':'$academicYear',
        'facultyId':'$faculties.facultyId',
        'dir_methodName':'$courseOutcomeDetailsForAttainment.directMethods.methodName',
        'dir_methodDescription':'$courseOutcomeDetailsForAttainment.directMethods.methodDescription',
        'dir_attainment':'$courseOutcomeDetailsForAttainment.directMethods.attainment',
        'dir_attainmentPercentage':'$courseOutcomeDetailsForAttainment.directMethods.attainmentPercentage',
        'indir_attainment':'$courseOutcomeDetailsForAttainment.indirectMethods.attainment',
        'indir_attainmentPercentage':'$courseOutcomeDetailsForAttainment.indirectMethods.attainmentPercentage',
        'indir_methodName':'$courseOutcomeDetailsForAttainment.indirectMethods.methodName',
        'indir_methodDescription':'$courseOutcomeDetailsForAttainment.indirectMethods.methodDescription',
        'totalAttainment':'$courseOutcomeDetailsForAttainment.totalAttainment',
        'directAttainment':'$courseOutcomeDetailsForAttainment.directAttainment',
        'indirectAttainment':'$courseOutcomeDetailsForAttainment.indirectAttainment'
        
        }
    }
    ])
    return list(attaiment_data)

# %%
def convert_(num):
    return [round(i,2) for i in num]

# %%
def get_required_attainment_detail(x):
    attaiment_data = db.dhi_generic_attainment_data.aggregate([
    {'$unwind':'$courseDetails'},
    {'$unwind':'$faculties'},
    {'$match':{
        'termNumber':x['termNumber'],
        'section':x['section'],
        'courseDetails.courseCode':x['courseCode'],
        'faculties.facultyId':x['facultyId'],
        'academicYear':x['year']
      }    
    },
        
    {'$unwind':'$courseOutcomeDetailsForAttainment'},

    {
      '$project':
        {
        '_id':0,
        'coNumber':'$courseOutcomeDetailsForAttainment.coNumber',
        'coTitle':'$courseOutcomeDetailsForAttainment.coTitle',
        'termNumber':'$termNumber',
        'section':'$section',
        'courseCode':'$courseDetails.courseCode',
        'courseName':'$courseDetails.courseName',
        'year':'$academicYear',
        'facultyId':'$faculties.facultyId',
        'totalAttainment':'$courseOutcomeDetailsForAttainment.totalAttainment',
        'directAttainment':'$courseOutcomeDetailsForAttainment.directAttainment',
        'indirectAttainment':'$courseOutcomeDetailsForAttainment.indirectAttainment'
        
        }
    }
    ])
    return list(attaiment_data)

# %%
def get_overall_attainment_data(facultyIdList,termList,year):
    overall_attainmnet_details = {}
    courses = db.dhi_lesson_plan.aggregate([
        {'$unwind':'$faculties'},
        {'$unwind':'$departments'},
        {'$match':
            {
            'faculties.facultyId':{'$in':facultyIdList},
            'academicYear':year,
            'departments.termNumber':{'$in':termList}
            }
        },
        {
        '$project':
            {
                '_id':0,
                'courseCode':1,
                'courseName':1,
                'termNumber':'$departments.termNumber',
                'section':'$departments.section',
                'facultyId':'$faculties.facultyId',
                'year':'$academicYear',
            } 
        }
        ])
    df = pd.DataFrame(courses)
    print(df)
    attainmnet_data = []
    df1 = df.copy()

    attainment_data = [get_attainment_details(df1.loc[i]) for i in range(len(df1))]
    attainment = list(itertools.chain.from_iterable(attainment_data))
    df2 = pd.DataFrame(data=attainment, columns=['coNumber','coTitle','termNumber','section','courseCode',
                                           'year','facultyId','dir_methodName','dir_methodDescription','dir_attainment',
                                            'dir_attainmentPercentage','indir_attainment','indir_attainmentPercentage',
                                           'indir_methodName','indir_methodDescription','totalAttainment','directAttainment','indirectAttainment'])
    df2['dir_attainment'] = df2['dir_attainment'].apply(convert_)
    df2['indir_attainment'] = df2['indir_attainment'].apply(convert_)
    df2['totalAttainment'] = df2['totalAttainment'].round(decimals=2)
    df2['directAttainment'] = df2['directAttainment'].round(decimals=2)
    df2['indirectAttainment'] = df2['indirectAttainment'].round(decimals=2)
    attainment_details = json.loads(df2.to_json(orient='records'))
    df3 = pd.pivot_table(df2, values=['totalAttainment','directAttainment','indirectAttainment'],
                         index=['termNumber','section','courseCode','coNumber','facultyId'], aggfunc=np.mean)
    co_wise_attainment_val = json.loads(df3.reset_index().to_json(orient="records"))
    required_attainment_data_ = [get_required_attainment_detail(df1.loc[i]) for i in range(len(df1))]
    required_attainment_data = list(itertools.chain.from_iterable(required_attainment_data_))
    data = pd.DataFrame(data=required_attainment_data, columns=['coNumber','coTitle','termNumber','section','courseCode',
                                           'year','facultyId','totalAttainment','directAttainment','indirectAttainment','courseName'])
    required_data = data.groupby(['termNumber','section','courseCode','facultyId','courseName'])
    average_attainment_data = list(required_data['totalAttainment'].mean())
    total_average_attainment = []
    for k, v in required_data:
        data_ = {}
        data_['termNumber'] = k[0]
        data_['courseCode'] = k[2]
        data_['section'] = k[1]
        data_['facultyId'] = k[3]
        data_['courseName'] = k[4]
        data_['average_attainment'] = round(v['totalAttainment'].mean(),2)
        total_average_attainment.append(data_)
    overall_attainmnet_details = {"Total_Attainmnet_Data":total_average_attainment,
    "Co_Wise_Atainmnet_Val":co_wise_attainment_val,"Attainmnet_Details":attainment_details}
    return overall_attainmnet_details

# %%
# get_overall_attainment_data(['462','465','359','621','380','763'],['1','2','3','4','5','6','7','8'],
#                                   '2018-19')
# Out:
# {'Total_Attainmnet_Data': [{'termNumber': '4',
#    'courseCode': '17CS43',
#    'section': 'B',
#    'facultyId': '380',
#    'courseName': 'DESIGN AND ANALYSIS OF ALGORITHMS',
#    'average_attainment': 39.01},
#   {'termNumber': '4',
#    'courseCode': '17CS44',
#    'section': 'B',
#    'facultyId': '462',
#    'courseName': 'MICROPROCESSORS AND MICROCONTROLLERS',
#    'average_attainment': 41.63},
#   {'termNumber': '5',
#    'courseCode': '15CS51',
#    'section': 'A',
#    'facultyId': '763',
#    'courseName': 'MANAGEMENT AND ENTREPRENEURSHIP FOR IT INDUSTRY',
#    'average_attainment': 85.25},
#   {'termNumber': '5',
#    'courseCode': '15CS52',
#    'section': 'A',
#    'facultyId': '462',
#    'courseName': 'COMPUTER NETWORKS',
#    'average_attainment': 70.93},
#   {'termNumber': '5',
#    'courseCode': '15CS53',
#    'section': 'A',
#    'facultyId': '380',
#    'courseName': 'DATABASE MANAGEMENT SYSTEM',
#    'average_attainment': 74.41},
#   {'termNumber': '5',
#    'courseCode': '15CS54',
#    'section': 'A',
#    'facultyId': '359',
#    'courseName': 'AUTOMATA THEORY AND COMPUTABILITY',
#    'average_attainment': 74.09},
#   {'termNumber': '5',
#    'courseCode': '15CS553',
#    'section': 'A',
#    'facultyId': '465',
#    'courseName': 'ADVANCED JAVA AND J2EE',
#    'average_attainment': 76.26},
#   {'termNumber': '5',
#    'courseCode': '15CS563',
#    'section': 'A',
#    'facultyId': '621',
#    'courseName': 'EMBEDDED COMPUTING SYSTEM',
#    'average_attainment': 76.42},
#   {'termNumber': '5',
#    'courseCode': '15CS51',
#    'section': 'B',
#    'facultyId': '763',
#    'courseName': 'MANAGEMENT AND ENTREPRENEURSHIP FOR IT INDUSTRY',
#    'average_attainment': 83.45},
#   {'termNumber': '5',
#    'courseCode': '15CS52',
#    'section': 'B',
#    'facultyId': '462',
#    'courseName': 'COMPUTER NETWORKS',
#    'average_attainment': 66.79},
#   {'termNumber': '5',
#    'courseCode': '15CS53',
#    'section': 'B',
#    'facultyId': '380',
#    'courseName': 'DATABASE MANAGEMENT SYSTEM',
#    'average_attainment': 75.2},
#   {'termNumber': '5',
#    'courseCode': '15CS54',
#    'section': 'B',
#    'facultyId': '359',
#    'courseName': 'AUTOMATA THEORY AND COMPUTABILITY',
#    'average_attainment': 69.05},
#   {'termNumber': '5',
#    'courseCode': '15CS553',
#    'section': 'B',
#    'facultyId': '465',
#    'courseName': 'ADVANCED JAVA AND J2EE',
#    'average_attainment': 80.29},
#   {'termNumber': '5',
#    'courseCode': '15CS563',
#    'section': 'B',
#    'facultyId': '621',
#    'courseName': 'EMBEDDED COMPUTING SYSTEM',
#    'average_attainment': 65.73},
#   {'termNumber': '6',
#    'courseCode': '15CS61',
#    'section': 'A',
#    'facultyId': '359',
#    'courseName': 'CRYPTOGRAPHY, NETWORK SECURITY AND CYBER LAW',
#    'average_attainment': 43.5},
#   {'termNumber': '6',
#    'courseCode': '15CS63',
#    'section': 'A',
#    'facultyId': '763',
#    'courseName': 'SYSTEM SOFTWARE AND COMPILER DESIGN',
#    'average_attainment': 41.33},
#   {'termNumber': '6',
#    'courseCode': '15CS61',
#    'section': 'B',
#    'facultyId': '359',
#    'courseName': 'CRYPTOGRAPHY, NETWORK SECURITY AND CYBER LAW',
#    'average_attainment': 46.78},
#   {'termNumber': '6',
#    'courseCode': '15CS63',
#    'section': 'B',
#    'facultyId': '763',
#    'courseName': 'SYSTEM SOFTWARE AND COMPILER DESIGN',
#    'average_attainment': 43.53}],
#  'Co_Wise_Atainmnet_Val': [{'termNumber': '4',
#    'section': 'B',
#    'courseCode': '17CS43',
#    'coNumber': 1,
#    'facultyId': '380',
#    'directAttainment': 36.44,
#    'indirectAttainment': 55.56,
#    'totalAttainment': 40.27},
#   {'termNumber': '4',
#    'section': 'B',
#    'courseCode': '17CS43',
#    'coNumber': 2,
#    'facultyId': '380',
#    'directAttainment': 34.19,
#    'indirectAttainment': 55.56,
#    'totalAttainment': 38.47},
#   {'termNumber': '4',
#    'section': 'B',
#    'courseCode': '17CS43',
#    'coNumber': 3,
#    'facultyId': '380',
#    'directAttainment': 28.44,
#    'indirectAttainment': 77.78,
#    'totalAttainment': 38.31},
#   {'termNumber': '4',
#    'section': 'B',
#    'courseCode': '17CS44',
#    'coNumber': 1,
#    'facultyId': '462',
#    'directAttainment': 36.95,
#    'indirectAttainment': 77.78,
#    'totalAttainment': 45.12},
#   {'termNumber': '4',
#    'section': 'B',
#    'courseCode': '17CS44',
#    'coNumber': 2,
#    'facultyId': '462',
#    'directAttainment': 30.67,
#    'indirectAttainment': 66.67,
#    'totalAttainment': 37.87},
#   {'termNumber': '4',
#    'section': 'B',
#    'courseCode': '17CS44',
#    'coNumber': 3,
#    'facultyId': '462',
#    'directAttainment': 36.62,
#    'indirectAttainment': 66.67,
#    'totalAttainment': 42.63},
#   {'termNumber': '4',
#    'section': 'B',
#    'courseCode': '17CS44',
#    'coNumber': 4,
#    'facultyId': '462',
#    'directAttainment': 40.0,
#    'indirectAttainment': 44.44,
#    'totalAttainment': 40.89},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS51',
#    'coNumber': 1,
#    'facultyId': '763',
#    'directAttainment': 84.77,
#    'indirectAttainment': 92.59,
#    'totalAttainment': 86.33},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS51',
#    'coNumber': 2,
#    'facultyId': '763',
#    'directAttainment': 84.38,
#    'indirectAttainment': 85.19,
#    'totalAttainment': 84.54},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS51',
#    'coNumber': 3,
#    'facultyId': '763',
#    'directAttainment': 84.82,
#    'indirectAttainment': 85.19,
#    'totalAttainment': 84.89},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS52',
#    'coNumber': 1,
#    'facultyId': '462',
#    'directAttainment': 79.97,
#    'indirectAttainment': 88.89,
#    'totalAttainment': 81.75},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS52',
#    'coNumber': 2,
#    'facultyId': '462',
#    'directAttainment': 82.56,
#    'indirectAttainment': 92.59,
#    'totalAttainment': 84.57},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS52',
#    'coNumber': 3,
#    'facultyId': '462',
#    'directAttainment': 70.64,
#    'indirectAttainment': 92.59,
#    'totalAttainment': 75.03},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS52',
#    'coNumber': 4,
#    'facultyId': '462',
#    'directAttainment': 70.8,
#    'indirectAttainment': 88.89,
#    'totalAttainment': 74.42},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS52',
#    'coNumber': 5,
#    'facultyId': '462',
#    'directAttainment': 48.64,
#    'indirectAttainment': 0.0,
#    'totalAttainment': 38.91},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS53',
#    'coNumber': 1,
#    'facultyId': '380',
#    'directAttainment': 73.01,
#    'indirectAttainment': 88.89,
#    'totalAttainment': 76.19},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS53',
#    'coNumber': 2,
#    'facultyId': '380',
#    'directAttainment': 65.11,
#    'indirectAttainment': 88.89,
#    'totalAttainment': 69.87},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS53',
#    'coNumber': 3,
#    'facultyId': '380',
#    'directAttainment': 71.62,
#    'indirectAttainment': 92.59,
#    'totalAttainment': 75.82},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS53',
#    'coNumber': 4,
#    'facultyId': '380',
#    'directAttainment': 72.5,
#    'indirectAttainment': 88.89,
#    'totalAttainment': 75.78},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS54',
#    'coNumber': 1,
#    'facultyId': '359',
#    'directAttainment': 78.19,
#    'indirectAttainment': 88.89,
#    'totalAttainment': 80.33},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS54',
#    'coNumber': 2,
#    'facultyId': '359',
#    'directAttainment': 77.83,
#    'indirectAttainment': 88.89,
#    'totalAttainment': 80.04},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS54',
#    'coNumber': 3,
#    'facultyId': '359',
#    'directAttainment': 71.23,
#    'indirectAttainment': 85.19,
#    'totalAttainment': 74.02},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS54',
#    'coNumber': 4,
#    'facultyId': '359',
#    'directAttainment': 74.48,
#    'indirectAttainment': 88.89,
#    'totalAttainment': 77.36},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS54',
#    'coNumber': 5,
#    'facultyId': '359',
#    'directAttainment': 73.36,
#    'indirectAttainment': 0.0,
#    'totalAttainment': 58.69},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS553',
#    'coNumber': 1,
#    'facultyId': '465',
#    'directAttainment': 77.06,
#    'indirectAttainment': 88.89,
#    'totalAttainment': 79.43},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS553',
#    'coNumber': 2,
#    'facultyId': '465',
#    'directAttainment': 77.67,
#    'indirectAttainment': 88.89,
#    'totalAttainment': 79.91},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS553',
#    'coNumber': 3,
#    'facultyId': '465',
#    'directAttainment': 68.7,
#    'indirectAttainment': 88.89,
#    'totalAttainment': 72.74},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS553',
#    'coNumber': 4,
#    'facultyId': '465',
#    'directAttainment': 68.96,
#    'indirectAttainment': 88.89,
#    'totalAttainment': 72.94},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS563',
#    'coNumber': 1,
#    'facultyId': '621',
#    'directAttainment': 78.34,
#    'indirectAttainment': 88.89,
#    'totalAttainment': 80.45},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS563',
#    'coNumber': 2,
#    'facultyId': '621',
#    'directAttainment': 79.26,
#    'indirectAttainment': 88.89,
#    'totalAttainment': 81.19},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS563',
#    'coNumber': 3,
#    'facultyId': '621',
#    'directAttainment': 68.99,
#    'indirectAttainment': 88.89,
#    'totalAttainment': 72.97},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS563',
#    'coNumber': 4,
#    'facultyId': '621',
#    'directAttainment': 66.6,
#    'indirectAttainment': 88.89,
#    'totalAttainment': 71.06},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS51',
#    'coNumber': 1,
#    'facultyId': '763',
#    'directAttainment': 81.03,
#    'indirectAttainment': 100.0,
#    'totalAttainment': 84.82},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS51',
#    'coNumber': 2,
#    'facultyId': '763',
#    'directAttainment': 81.85,
#    'indirectAttainment': 100.0,
#    'totalAttainment': 85.48},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS51',
#    'coNumber': 3,
#    'facultyId': '763',
#    'directAttainment': 75.07,
#    'indirectAttainment': 100.0,
#    'totalAttainment': 80.06},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS52',
#    'coNumber': 1,
#    'facultyId': '462',
#    'directAttainment': 65.7,
#    'indirectAttainment': 100.0,
#    'totalAttainment': 72.56},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS52',
#    'coNumber': 2,
#    'facultyId': '462',
#    'directAttainment': 67.55,
#    'indirectAttainment': 100.0,
#    'totalAttainment': 74.04},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS52',
#    'coNumber': 3,
#    'facultyId': '462',
#    'directAttainment': 56.0,
#    'indirectAttainment': 100.0,
#    'totalAttainment': 64.8},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS52',
#    'coNumber': 4,
#    'facultyId': '462',
#    'directAttainment': 63.18,
#    'indirectAttainment': 100.0,
#    'totalAttainment': 70.54},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS52',
#    'coNumber': 5,
#    'facultyId': '462',
#    'directAttainment': 40.0,
#    'indirectAttainment': 100.0,
#    'totalAttainment': 52.0},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS53',
#    'coNumber': 1,
#    'facultyId': '380',
#    'directAttainment': 70.87,
#    'indirectAttainment': 100.0,
#    'totalAttainment': 76.7},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS53',
#    'coNumber': 2,
#    'facultyId': '380',
#    'directAttainment': 65.93,
#    'indirectAttainment': 100.0,
#    'totalAttainment': 72.75},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS53',
#    'coNumber': 3,
#    'facultyId': '380',
#    'directAttainment': 68.75,
#    'indirectAttainment': 100.0,
#    'totalAttainment': 75.0},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS53',
#    'coNumber': 4,
#    'facultyId': '380',
#    'directAttainment': 70.42,
#    'indirectAttainment': 100.0,
#    'totalAttainment': 76.34},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS54',
#    'coNumber': 1,
#    'facultyId': '359',
#    'directAttainment': 79.08,
#    'indirectAttainment': 100.0,
#    'totalAttainment': 83.26},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS54',
#    'coNumber': 2,
#    'facultyId': '359',
#    'directAttainment': 79.03,
#    'indirectAttainment': 100.0,
#    'totalAttainment': 83.22},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS54',
#    'coNumber': 3,
#    'facultyId': '359',
#    'directAttainment': 68.19,
#    'indirectAttainment': 100.0,
#    'totalAttainment': 74.55},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS54',
#    'coNumber': 4,
#    'facultyId': '359',
#    'directAttainment': 65.21,
#    'indirectAttainment': 0.0,
#    'totalAttainment': 52.17},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS54',
#    'coNumber': 5,
#    'facultyId': '359',
#    'directAttainment': 65.05,
#    'indirectAttainment': 0.0,
#    'totalAttainment': 52.04},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS553',
#    'coNumber': 1,
#    'facultyId': '465',
#    'directAttainment': 79.19,
#    'indirectAttainment': 100.0,
#    'totalAttainment': 83.35},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS553',
#    'coNumber': 2,
#    'facultyId': '465',
#    'directAttainment': 79.46,
#    'indirectAttainment': 100.0,
#    'totalAttainment': 83.57},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS553',
#    'coNumber': 3,
#    'facultyId': '465',
#    'directAttainment': 71.94,
#    'indirectAttainment': 100.0,
#    'totalAttainment': 77.55},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS553',
#    'coNumber': 4,
#    'facultyId': '465',
#    'directAttainment': 70.86,
#    'indirectAttainment': 100.0,
#    'totalAttainment': 76.69},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS563',
#    'coNumber': 1,
#    'facultyId': '621',
#    'directAttainment': 72.42,
#    'indirectAttainment': 100.0,
#    'totalAttainment': 77.94},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS563',
#    'coNumber': 2,
#    'facultyId': '621',
#    'directAttainment': 69.28,
#    'indirectAttainment': 100.0,
#    'totalAttainment': 75.42},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS563',
#    'coNumber': 3,
#    'facultyId': '621',
#    'directAttainment': 73.34,
#    'indirectAttainment': 0.0,
#    'totalAttainment': 58.67},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS563',
#    'coNumber': 4,
#    'facultyId': '621',
#    'directAttainment': 63.63,
#    'indirectAttainment': 0.0,
#    'totalAttainment': 50.9},
#   {'termNumber': '6',
#    'section': 'A',
#    'courseCode': '15CS61',
#    'coNumber': 1,
#    'facultyId': '359',
#    'directAttainment': 31.97,
#    'indirectAttainment': 87.1,
#    'totalAttainment': 43.0},
#   {'termNumber': '6',
#    'section': 'A',
#    'courseCode': '15CS61',
#    'coNumber': 2,
#    'facultyId': '359',
#    'directAttainment': 32.36,
#    'indirectAttainment': 84.95,
#    'totalAttainment': 42.88},
#   {'termNumber': '6',
#    'section': 'A',
#    'courseCode': '15CS61',
#    'coNumber': 3,
#    'facultyId': '359',
#    'directAttainment': 34.56,
#    'indirectAttainment': 84.95,
#    'totalAttainment': 44.64},
#   {'termNumber': '6',
#    'section': 'A',
#    'courseCode': '15CS63',
#    'coNumber': 1,
#    'facultyId': '763',
#    'directAttainment': 21.82,
#    'indirectAttainment': 86.02,
#    'totalAttainment': 34.66},
#   {'termNumber': '6',
#    'section': 'A',
#    'courseCode': '15CS63',
#    'coNumber': 2,
#    'facultyId': '763',
#    'directAttainment': 32.38,
#    'indirectAttainment': 82.8,
#    'totalAttainment': 42.47},
#   {'termNumber': '6',
#    'section': 'A',
#    'courseCode': '15CS63',
#    'coNumber': 3,
#    'facultyId': '763',
#    'directAttainment': 37.62,
#    'indirectAttainment': 83.87,
#    'totalAttainment': 46.87},
#   {'termNumber': '6',
#    'section': 'B',
#    'courseCode': '15CS61',
#    'coNumber': 1,
#    'facultyId': '359',
#    'directAttainment': 37.36,
#    'indirectAttainment': 97.22,
#    'totalAttainment': 49.34},
#   {'termNumber': '6',
#    'section': 'B',
#    'courseCode': '15CS61',
#    'coNumber': 2,
#    'facultyId': '359',
#    'directAttainment': 32.17,
#    'indirectAttainment': 98.61,
#    'totalAttainment': 45.46},
#   {'termNumber': '6',
#    'section': 'B',
#    'courseCode': '15CS61',
#    'coNumber': 3,
#    'facultyId': '359',
#    'directAttainment': 32.29,
#    'indirectAttainment': 98.61,
#    'totalAttainment': 45.56},
#   {'termNumber': '6',
#    'section': 'B',
#    'courseCode': '15CS63',
#    'coNumber': 1,
#    'facultyId': '763',
#    'directAttainment': 22.95,
#    'indirectAttainment': 97.1,
#    'totalAttainment': 37.78},
#   {'termNumber': '6',
#    'section': 'B',
#    'courseCode': '15CS63',
#    'coNumber': 2,
#    'facultyId': '763',
#    'directAttainment': 33.25,
#    'indirectAttainment': 98.55,
#    'totalAttainment': 46.31},
#   {'termNumber': '6',
#    'section': 'B',
#    'courseCode': '15CS63',
#    'coNumber': 3,
#    'facultyId': '763',
#    'directAttainment': 33.85,
#    'indirectAttainment': 97.1,
#    'totalAttainment': 46.5}],
#  'Attainmnet_Details': [{'coNumber': 1,
#    'coTitle': 'Explain principles of application layer protocols',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS52',
#    'year': '2018-19',
#    'facultyId': '462',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [78.42, 81.06, 78.03],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [88.89],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 81.75,
#    'directAttainment': 79.97,
#    'indirectAttainment': 88.89},
#   {'coNumber': 2,
#    'coTitle': 'Recognize transport layer services and infer UDP and TCP protocols',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS52',
#    'year': '2018-19',
#    'facultyId': '462',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [87.08, 81.06, 78.03],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [92.59],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 84.57,
#    'directAttainment': 82.56,
#    'indirectAttainment': 92.59},
#   {'coNumber': 3,
#    'coTitle': 'Classify routers, IP and Routing Algorithms in network layer',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS52',
#    'year': '2018-19',
#    'facultyId': '462',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [73.33, 81.06, 0.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [92.59],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 75.03,
#    'directAttainment': 70.64,
#    'indirectAttainment': 92.59},
#   {'coNumber': 4,
#    'coTitle': 'Understand the Wireless and Mobile Networks covering IEEE 802.11 Standard',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS52',
#    'year': '2018-19',
#    'facultyId': '462',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [73.87, 81.06, 0.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [88.89],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 74.42,
#    'directAttainment': 70.8,
#    'indirectAttainment': 88.89},
#   {'coNumber': 5,
#    'coTitle': 'Describe Multimedia Networking and Network Management',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS52',
#    'year': '2018-19',
#    'facultyId': '462',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [0.0, 81.06, 0.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [0.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 38.91,
#    'directAttainment': 48.64,
#    'indirectAttainment': 0.0},
#   {'coNumber': 1,
#    'coTitle': 'Explain principles of application layer protocols',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS52',
#    'year': '2018-19',
#    'facultyId': '462',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [85.68, 66.67, 0.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [100.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 72.56,
#    'directAttainment': 65.7,
#    'indirectAttainment': 100.0},
#   {'coNumber': 2,
#    'coTitle': 'Recognize transport layer services and infer UDP and TCP protocols',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS52',
#    'year': '2018-19',
#    'facultyId': '462',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [91.83, 66.67, 0.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [100.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 74.04,
#    'directAttainment': 67.55,
#    'indirectAttainment': 100.0},
#   {'coNumber': 3,
#    'coTitle': 'Classify routers, IP and Routing Algorithms in network layer',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS52',
#    'year': '2018-19',
#    'facultyId': '462',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [53.33, 66.67, 0.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [100.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 64.8,
#    'directAttainment': 56.0,
#    'indirectAttainment': 100.0},
#   {'coNumber': 4,
#    'coTitle': 'Understand the Wireless and Mobile Networks covering IEEE 802.11 Standard',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS52',
#    'year': '2018-19',
#    'facultyId': '462',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [77.25, 66.67, 0.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [100.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 70.54,
#    'directAttainment': 63.18,
#    'indirectAttainment': 100.0},
#   {'coNumber': 5,
#    'coTitle': 'Describe Multimedia Networking and Network Management',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS52',
#    'year': '2018-19',
#    'facultyId': '462',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [0.0, 66.67, 0.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [100.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 52.0,
#    'directAttainment': 40.0,
#    'indirectAttainment': 100.0},
#   {'coNumber': 1,
#    'coTitle': 'Interpret the need for advanced Java concepts like enumerations and collections in developing modular and efficient programs',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS553',
#    'year': '2018-19',
#    'facultyId': '465',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [87.24, 70.45, 86.19],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [88.89],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 79.43,
#    'directAttainment': 77.06,
#    'indirectAttainment': 88.89},
#   {'coNumber': 2,
#    'coTitle': 'Demonstrate various String Handling Mechanism',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS553',
#    'year': '2018-19',
#    'facultyId': '465',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [85.66, 70.45, 96.97],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [88.89],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 79.91,
#    'directAttainment': 77.67,
#    'indirectAttainment': 88.89},
#   {'coNumber': 3,
#    'coTitle': 'Describe how servlets fit into Java-based web application architecture',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS553',
#    'year': '2018-19',
#    'facultyId': '465',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [88.09, 70.45, 0.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [88.89],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 72.74,
#    'directAttainment': 68.7,
#    'indirectAttainment': 88.89},
#   {'coNumber': 4,
#    'coTitle': 'Illustrate database access and details for managing information using the JDBC API',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS553',
#    'year': '2018-19',
#    'facultyId': '465',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [88.95, 70.45, 0.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [88.89],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 72.94,
#    'directAttainment': 68.96,
#    'indirectAttainment': 88.89},
#   {'coNumber': 1,
#    'coTitle': 'Interpret the need for advanced Java concepts like enumerations and collections in developing modular and efficient programs',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS553',
#    'year': '2018-19',
#    'facultyId': '465',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [90.53, 71.43, 91.73],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [100.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 83.35,
#    'directAttainment': 79.19,
#    'indirectAttainment': 100.0},
#   {'coNumber': 2,
#    'coTitle': 'Demonstrate various String Handling Mechanism',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS553',
#    'year': '2018-19',
#    'facultyId': '465',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [89.6, 71.43, 97.22],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [100.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 83.57,
#    'directAttainment': 79.46,
#    'indirectAttainment': 100.0},
#   {'coNumber': 3,
#    'coTitle': 'Describe how servlets fit into Java-based web application architecture',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS553',
#    'year': '2018-19',
#    'facultyId': '465',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [96.94, 71.43, 0.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [100.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 77.55,
#    'directAttainment': 71.94,
#    'indirectAttainment': 100.0},
#   {'coNumber': 4,
#    'coTitle': 'Illustrate database access and details for managing information using the JDBC API',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS553',
#    'year': '2018-19',
#    'facultyId': '465',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [93.33, 71.43, 0.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [100.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 76.69,
#    'directAttainment': 70.86,
#    'indirectAttainment': 100.0},
#   {'coNumber': 1,
#    'coTitle': 'Acquire fundamental understanding of the core concepts in automata theory\nand Theory of Computation',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS54',
#    'year': '2018-19',
#    'facultyId': '359',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [92.4, 69.7, 86.51],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [88.89],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 80.33,
#    'directAttainment': 78.19,
#    'indirectAttainment': 88.89},
#   {'coNumber': 2,
#    'coTitle': 'Learn how to translate between different models of Computation (e.g.,\nDeterministic and Non-deterministic and Software models)',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS54',
#    'year': '2018-19',
#    'facultyId': '359',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [92.42, 69.7, 82.8],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [88.89],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 80.04,
#    'directAttainment': 77.83,
#    'indirectAttainment': 88.89},
#   {'coNumber': 3,
#    'coTitle': 'Design Grammars and Automata (recognizers) for different language classes\nand become knowledgeable about restricted models of Computation\n(Regular, Context Free) and their relative powers',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS54',
#    'year': '2018-19',
#    'facultyId': '359',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [71.68, 69.7, 79.09],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [85.19],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 74.02,
#    'directAttainment': 71.23,
#    'indirectAttainment': 85.19},
#   {'coNumber': 4,
#    'coTitle': 'Develop skills in formal reasoning and reduction of a problem to a formal\nmodel, with an emphasis on semantic precision and conciseness',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS54',
#    'year': '2018-19',
#    'facultyId': '359',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [82.52, 69.7, 79.09],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [88.89],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 77.36,
#    'directAttainment': 74.48,
#    'indirectAttainment': 88.89},
#   {'coNumber': 5,
#    'coTitle': 'Classify a problem with respect to different models of Computation',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS54',
#    'year': '2018-19',
#    'facultyId': '359',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [71.79, 69.7, 100.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [0.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 58.69,
#    'directAttainment': 73.36,
#    'indirectAttainment': 0.0},
#   {'coNumber': 1,
#    'coTitle': 'Acquire fundamental understanding of the core concepts in automata theory\nand Theory of Computation',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS54',
#    'year': '2018-19',
#    'facultyId': '359',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [93.81, 69.52, 92.22],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [100.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 83.26,
#    'directAttainment': 79.08,
#    'indirectAttainment': 100.0},
#   {'coNumber': 2,
#    'coTitle': 'Learn how to translate between different models of Computation (e.g.,\nDeterministic and Non-deterministic and Software models)',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS54',
#    'year': '2018-19',
#    'facultyId': '359',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [93.64, 69.52, 92.22],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [100.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 83.22,
#    'directAttainment': 79.03,
#    'indirectAttainment': 100.0},
#   {'coNumber': 3,
#    'coTitle': 'Design Grammars and Automata (recognizers) for different language classes\nand become knowledgeable about restricted models of Computation\n(Regular, Context Free) and their relative powers',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS54',
#    'year': '2018-19',
#    'facultyId': '359',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [88.26, 69.52, 0.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [100.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 74.55,
#    'directAttainment': 68.19,
#    'indirectAttainment': 100.0},
#   {'coNumber': 4,
#    'coTitle': 'Develop skills in formal reasoning and reduction of a problem to a formal\nmodel, with an emphasis on semantic precision and conciseness',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS54',
#    'year': '2018-19',
#    'facultyId': '359',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [78.33, 69.52, 0.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [0.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 52.17,
#    'directAttainment': 65.21,
#    'indirectAttainment': 0.0},
#   {'coNumber': 5,
#    'coTitle': 'Classify a problem with respect to different models of Computation',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS54',
#    'year': '2018-19',
#    'facultyId': '359',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [77.78, 69.52, 0.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [0.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 52.04,
#    'directAttainment': 65.05,
#    'indirectAttainment': 0.0},
#   {'coNumber': 1,
#    'coTitle': 'Distinguish the characteristics of embedded computer systems',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS563',
#    'year': '2018-19',
#    'facultyId': '621',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [86.99, 75.76, 67.88],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [88.89],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 80.45,
#    'directAttainment': 78.34,
#    'indirectAttainment': 88.89},
#   {'coNumber': 2,
#    'coTitle': 'Examine the various vulnerabilities of embedded computer systems',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS563',
#    'year': '2018-19',
#    'facultyId': '621',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [89.61, 75.76, 69.24],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [88.89],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 81.19,
#    'directAttainment': 79.26,
#    'indirectAttainment': 88.89},
#   {'coNumber': 3,
#    'coTitle': 'design and develop modules using RTOS',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS563',
#    'year': '2018-19',
#    'facultyId': '621',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [55.36, 75.76, 69.24],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [88.89],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 72.97,
#    'directAttainment': 68.99,
#    'indirectAttainment': 88.89},
#   {'coNumber': 4,
#    'coTitle': 'Implement RPC, threads and tasks',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS563',
#    'year': '2018-19',
#    'facultyId': '621',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [70.5, 75.76, 0.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [88.89],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 71.06,
#    'directAttainment': 66.6,
#    'indirectAttainment': 88.89},
#   {'coNumber': 1,
#    'coTitle': 'Distinguish the characteristics of embedded computer systems',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS563',
#    'year': '2018-19',
#    'facultyId': '621',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [81.98, 69.52, 61.11],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [100.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 77.94,
#    'directAttainment': 72.42,
#    'indirectAttainment': 100.0},
#   {'coNumber': 2,
#    'coTitle': 'Examine the various vulnerabilities of embedded computer systems',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS563',
#    'year': '2018-19',
#    'facultyId': '621',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [64.1, 69.52, 83.33],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [100.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 75.42,
#    'directAttainment': 69.28,
#    'indirectAttainment': 100.0},
#   {'coNumber': 3,
#    'coTitle': 'design and develop modules using RTOS',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS563',
#    'year': '2018-19',
#    'facultyId': '621',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [77.65, 69.52, 83.33],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [0.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 58.67,
#    'directAttainment': 73.34,
#    'indirectAttainment': 0.0},
#   {'coNumber': 4,
#    'coTitle': 'implement RPC,threads and tasks',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS563',
#    'year': '2018-19',
#    'facultyId': '621',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [73.05, 69.52, 0.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [0.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 50.9,
#    'directAttainment': 63.63,
#    'indirectAttainment': 0.0},
#   {'coNumber': 1,
#    'coTitle': 'Identify, analyze and define database objects, enforce integrity constraints on a\ndatabase using RDBMS',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS53',
#    'year': '2018-19',
#    'facultyId': '380',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [96.23, 53.33, 100.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [100.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 76.7,
#    'directAttainment': 70.87,
#    'indirectAttainment': 100.0},
#   {'coNumber': 2,
#    'coTitle': 'Use Structured Query Language (SQL) for database manipulation',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS53',
#    'year': '2018-19',
#    'facultyId': '380',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [84.77, 53.33, 85.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [100.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 72.75,
#    'directAttainment': 65.93,
#    'indirectAttainment': 100.0},
#   {'coNumber': 3,
#    'coTitle': 'Design and build simple database systems',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS53',
#    'year': '2018-19',
#    'facultyId': '380',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [89.18, 53.33, 100.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [100.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 75.0,
#    'directAttainment': 68.75,
#    'indirectAttainment': 100.0},
#   {'coNumber': 4,
#    'coTitle': 'Design and build GUI application to interact with databases',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS53',
#    'year': '2018-19',
#    'facultyId': '380',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [94.74, 53.33, 100.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [100.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 76.34,
#    'directAttainment': 70.42,
#    'indirectAttainment': 100.0},
#   {'coNumber': 1,
#    'coTitle': 'Identify, analyze and define database objects, enforce integrity constraints on a\ndatabase using RDBMS',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS53',
#    'year': '2018-19',
#    'facultyId': '380',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [93.37, 58.33, 100.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [88.89],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 76.19,
#    'directAttainment': 73.01,
#    'indirectAttainment': 88.89},
#   {'coNumber': 2,
#    'coTitle': 'Use Structured Query Language (SQL) for database manipulation',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS53',
#    'year': '2018-19',
#    'facultyId': '380',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [77.04, 58.33, 70.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [88.89],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 69.87,
#    'directAttainment': 65.11,
#    'indirectAttainment': 88.89},
#   {'coNumber': 3,
#    'coTitle': 'Design and build simple database systems',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS53',
#    'year': '2018-19',
#    'facultyId': '380',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [88.74, 58.33, 100.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [92.59],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 75.82,
#    'directAttainment': 71.62,
#    'indirectAttainment': 92.59},
#   {'coNumber': 4,
#    'coTitle': 'Design and build GUI application to interact with databases',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS53',
#    'year': '2018-19',
#    'facultyId': '380',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [91.67, 58.33, 100.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [88.89],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 75.78,
#    'directAttainment': 72.5,
#    'indirectAttainment': 88.89},
#   {'coNumber': 1,
#    'coTitle': 'Define management, organization, entrepreneur, planning, staffing, ERP and outline\ntheir importance in entrepreneurship',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS51',
#    'year': '2018-19',
#    'facultyId': '763',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [90.89, 79.55, 97.73],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [92.59],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 86.33,
#    'directAttainment': 84.77,
#    'indirectAttainment': 92.59},
#   {'coNumber': 2,
#    'coTitle': 'Utilize the resources available effectively through ERP',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS51',
#    'year': '2018-19',
#    'facultyId': '763',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [91.55, 79.55, 91.82],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [85.19],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 84.54,
#    'directAttainment': 84.38,
#    'indirectAttainment': 85.19},
#   {'coNumber': 3,
#    'coTitle': 'Make us of IPRs and institutional support in entrepreneurship',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS51',
#    'year': '2018-19',
#    'facultyId': '763',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [91.07, 79.55, 97.73],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [85.19],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 84.89,
#    'directAttainment': 84.82,
#    'indirectAttainment': 85.19},
#   {'coNumber': 1,
#    'coTitle': 'Define management, organization, entrepreneur, planning, staffing, ERP and outline\ntheir importance in entrepreneurship',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS51',
#    'year': '2018-19',
#    'facultyId': '763',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [88.2, 74.29, 100.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [100.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 84.82,
#    'directAttainment': 81.03,
#    'indirectAttainment': 100.0},
#   {'coNumber': 2,
#    'coTitle': 'Utilize the resources available effectively through ERP',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS51',
#    'year': '2018-19',
#    'facultyId': '763',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [93.51, 74.29, 92.22],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [100.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 85.48,
#    'directAttainment': 81.85,
#    'indirectAttainment': 100.0},
#   {'coNumber': 3,
#    'coTitle': 'Make us of IPRs and institutional support in entrepreneurship',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS51',
#    'year': '2018-19',
#    'facultyId': '763',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [68.34, 74.29, 100.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [100.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 80.06,
#    'directAttainment': 75.07,
#    'indirectAttainment': 100.0},
#   {'coNumber': 1,
#    'coTitle': 'Discuss cryptography and its need to various applications ',
#    'termNumber': '6',
#    'section': 'A',
#    'courseCode': '15CS61',
#    'year': '2018-19',
#    'facultyId': '359',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [83.54, 0.0, 69.09],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [87.1],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 43.0,
#    'directAttainment': 31.97,
#    'indirectAttainment': 87.1},
#   {'coNumber': 2,
#    'coTitle': 'Design and develop simple cryptography algorithms \n',
#    'termNumber': '6',
#    'section': 'A',
#    'courseCode': '15CS61',
#    'year': '2018-19',
#    'facultyId': '359',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [85.06, 0.0, 68.41],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [84.95],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 42.88,
#    'directAttainment': 32.36,
#    'indirectAttainment': 84.95},
#   {'coNumber': 3,
#    'coTitle': 'Understand cyber security and need cyber Law ',
#    'termNumber': '6',
#    'section': 'A',
#    'courseCode': '15CS61',
#    'year': '2018-19',
#    'facultyId': '359',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [92.79, 0.0, 67.27],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [84.95],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 44.64,
#    'directAttainment': 34.56,
#    'indirectAttainment': 84.95},
#   {'coNumber': 1,
#    'coTitle': 'Discuss cryptography and its need to various applications ',
#    'termNumber': '6',
#    'section': 'B',
#    'courseCode': '15CS61',
#    'year': '2018-19',
#    'facultyId': '359',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [93.07, 0.0, 94.44],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [97.22],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 49.34,
#    'directAttainment': 37.36,
#    'indirectAttainment': 97.22},
#   {'coNumber': 2,
#    'coTitle': 'Design and develop simple cryptography algorithms \n',
#    'termNumber': '6',
#    'section': 'B',
#    'courseCode': '15CS61',
#    'year': '2018-19',
#    'facultyId': '359',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [87.99, 0.0, 57.78],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [98.61],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 45.46,
#    'directAttainment': 32.17,
#    'indirectAttainment': 98.61},
#   {'coNumber': 3,
#    'coTitle': 'Understand cyber security and need cyber Law ',
#    'termNumber': '6',
#    'section': 'B',
#    'courseCode': '15CS61',
#    'year': '2018-19',
#    'facultyId': '359',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [88.38, 0.0, 57.78],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [98.61],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 45.56,
#    'directAttainment': 32.29,
#    'indirectAttainment': 98.61},
#   {'coNumber': 1,
#    'coTitle': 'Explain system software such as assemblers, loaders, linkers and macroprocessors',
#    'termNumber': '6',
#    'section': 'B',
#    'courseCode': '15CS63',
#    'year': '2018-19',
#    'facultyId': '763',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [45.03, 0.0, 94.44],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [97.1],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 37.78,
#    'directAttainment': 22.95,
#    'indirectAttainment': 97.1},
#   {'coNumber': 2,
#    'coTitle': 'Design and develop lexical analyzers, parsers and code generators',
#    'termNumber': '6',
#    'section': 'B',
#    'courseCode': '15CS63',
#    'year': '2018-19',
#    'facultyId': '763',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [86.29, 0.0, 73.61],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [98.55],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 46.31,
#    'directAttainment': 33.25,
#    'indirectAttainment': 98.55},
#   {'coNumber': 3,
#    'coTitle': 'Utilize lex and yacc tools for implementing different concepts of system software',
#    'termNumber': '6',
#    'section': 'B',
#    'courseCode': '15CS63',
#    'year': '2018-19',
#    'facultyId': '763',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [89.06, 0.0, 71.3],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [97.1],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 46.5,
#    'directAttainment': 33.85,
#    'indirectAttainment': 97.1},
#   {'coNumber': 1,
#    'coTitle': 'Explain system software such as assemblers, loaders, linkers and macroprocessors',
#    'termNumber': '6',
#    'section': 'A',
#    'courseCode': '15CS63',
#    'year': '2018-19',
#    'facultyId': '763',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [43.95, 0.0, 86.36],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [86.02],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 34.66,
#    'directAttainment': 21.82,
#    'indirectAttainment': 86.02},
#   {'coNumber': 2,
#    'coTitle': 'Design and develop lexical analyzers, parsers and code generators',
#    'termNumber': '6',
#    'section': 'A',
#    'courseCode': '15CS63',
#    'year': '2018-19',
#    'facultyId': '763',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [81.12, 0.0, 80.48],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [82.8],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 42.47,
#    'directAttainment': 32.38,
#    'indirectAttainment': 82.8},
#   {'coNumber': 3,
#    'coTitle': 'Utilize lex and yacc tools for implementing different concepts of system software',
#    'termNumber': '6',
#    'section': 'A',
#    'courseCode': '15CS63',
#    'year': '2018-19',
#    'facultyId': '763',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [95.6, 0.0, 89.39],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [83.87],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 46.87,
#    'directAttainment': 37.62,
#    'indirectAttainment': 83.87},
#   {'coNumber': 1,
#    'coTitle': 'Describe computational solution to well known problems like searching, sorting etc.',
#    'termNumber': '4',
#    'section': 'B',
#    'courseCode': '17CS43',
#    'year': '2018-19',
#    'facultyId': '380',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['OA'],
#    'dir_attainment': [88.89, 0.0, 100.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [55.56],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': [' CES'],
#    'totalAttainment': 40.27,
#    'directAttainment': 36.44,
#    'indirectAttainment': 55.56},
#   {'coNumber': 2,
#    'coTitle': 'Estimate the computational complexity of different algorithms.',
#    'termNumber': '4',
#    'section': 'B',
#    'courseCode': '17CS43',
#    'year': '2018-19',
#    'facultyId': '380',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['OA'],
#    'dir_attainment': [85.19, 0.0, 86.67],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [55.56],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': [' CES'],
#    'totalAttainment': 38.47,
#    'directAttainment': 34.19,
#    'indirectAttainment': 55.56},
#   {'coNumber': 3,
#    'coTitle': 'Devise an algorithm using appropriate design strategies for problem solving.',
#    'termNumber': '4',
#    'section': 'B',
#    'courseCode': '17CS43',
#    'year': '2018-19',
#    'facultyId': '380',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['OA'],
#    'dir_attainment': [63.89, 0.0, 100.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [77.78],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': [' CES'],
#    'totalAttainment': 38.31,
#    'directAttainment': 28.44,
#    'indirectAttainment': 77.78},
#   {'coNumber': 1,
#    'coTitle': 'Differentiate between microprocessors and microcontrollers',
#    'termNumber': '4',
#    'section': 'B',
#    'courseCode': '17CS44',
#    'year': '2018-19',
#    'facultyId': '462',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['OA'],
#    'dir_attainment': [90.48, 0.0, 100.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [77.78],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': [' CES'],
#    'totalAttainment': 45.12,
#    'directAttainment': 36.95,
#    'indirectAttainment': 77.78},
#   {'coNumber': 2,
#    'coTitle': 'Design and develop assembly language code to solve problems',
#    'termNumber': '4',
#    'section': 'B',
#    'courseCode': '17CS44',
#    'year': '2018-19',
#    'facultyId': '462',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['OA'],
#    'dir_attainment': [70.83, 0.0, 100.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [66.67],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': [' CES'],
#    'totalAttainment': 37.87,
#    'directAttainment': 30.67,
#    'indirectAttainment': 66.67},
#   {'coNumber': 3,
#    'coTitle': 'Gain the knowledge for interfacing various devices to x86 family and ARM processor',
#    'termNumber': '4',
#    'section': 'B',
#    'courseCode': '17CS44',
#    'year': '2018-19',
#    'facultyId': '462',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['OA'],
#    'dir_attainment': [89.44, 0.0, 100.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [66.67],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': [' CES'],
#    'totalAttainment': 42.63,
#    'directAttainment': 36.62,
#    'indirectAttainment': 66.67},
#   {'coNumber': 4,
#    'coTitle': 'Demonstrate design of interrupt routines for interfacing devices',
#    'termNumber': '4',
#    'section': 'B',
#    'courseCode': '17CS44',
#    'year': '2018-19',
#    'facultyId': '462',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['OA'],
#    'dir_attainment': [100.0, 0.0, 0.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [44.44],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': [' CES'],
#    'totalAttainment': 40.89,
#    'directAttainment': 40.0,
#    'indirectAttainment': 44.44}]}

# %%
hodDetails('368', '2018-19', '5', 'BE')
# Out:
#    courseCode                                       courseName termNumber  \
# 0      15CS52                                COMPUTER NETWORKS          5
# 1      15CS52                                COMPUTER NETWORKS          5
# 2     15CS553                           ADVANCED JAVA AND J2EE          5
# 3     15CS553                           ADVANCED JAVA AND J2EE          5
# 4      15CS54                AUTOMATA THEORY AND COMPUTABILITY          5
# 5      15CS54                AUTOMATA THEORY AND COMPUTABILITY          5
# 6     15CS563                        EMBEDDED COMPUTING SYSTEM          5
# 7     15CS563                        EMBEDDED COMPUTING SYSTEM          5
# 8      15CS53                       DATABASE MANAGEMENT SYSTEM          5
# 9      15CS53                       DATABASE MANAGEMENT SYSTEM          5
# 10     15CS51  MANAGEMENT AND ENTREPRENEURSHIP FOR IT INDUSTRY          5
# 11     15CS51  MANAGEMENT AND ENTREPRENEURSHIP FOR IT INDUSTRY          5
#
#    section facultyId     year
# 0        A       462  2018-19
# 1        B       462  2018-19
# 2        A       465  2018-19
# 3        B       465  2018-19
# 4        A       359  2018-19
# 5        B       359  2018-19
# 6        A       621  2018-19
# 7        B       621  2018-19
# 8        B       380  2018-19
# 9        A       380  2018-19
# 10       A       763  2018-19
# 11       B       763  2018-19
# {'Total_Attainmnet_Data': [{'termNumber': '5',
#    'courseCode': '15CS51',
#    'section': 'A',
#    'facultyId': '763',
#    'courseName': 'MANAGEMENT AND ENTREPRENEURSHIP FOR IT INDUSTRY',
#    'average_attainment': 85.25},
#   {'termNumber': '5',
#    'courseCode': '15CS52',
#    'section': 'A',
#    'facultyId': '462',
#    'courseName': 'COMPUTER NETWORKS',
#    'average_attainment': 70.93},
#   {'termNumber': '5',
#    'courseCode': '15CS53',
#    'section': 'A',
#    'facultyId': '380',
#    'courseName': 'DATABASE MANAGEMENT SYSTEM',
#    'average_attainment': 74.41},
#   {'termNumber': '5',
#    'courseCode': '15CS54',
#    'section': 'A',
#    'facultyId': '359',
#    'courseName': 'AUTOMATA THEORY AND COMPUTABILITY',
#    'average_attainment': 74.09},
#   {'termNumber': '5',
#    'courseCode': '15CS553',
#    'section': 'A',
#    'facultyId': '465',
#    'courseName': 'ADVANCED JAVA AND J2EE',
#    'average_attainment': 76.26},
#   {'termNumber': '5',
#    'courseCode': '15CS563',
#    'section': 'A',
#    'facultyId': '621',
#    'courseName': 'EMBEDDED COMPUTING SYSTEM',
#    'average_attainment': 76.42},
#   {'termNumber': '5',
#    'courseCode': '15CS51',
#    'section': 'B',
#    'facultyId': '763',
#    'courseName': 'MANAGEMENT AND ENTREPRENEURSHIP FOR IT INDUSTRY',
#    'average_attainment': 83.45},
#   {'termNumber': '5',
#    'courseCode': '15CS52',
#    'section': 'B',
#    'facultyId': '462',
#    'courseName': 'COMPUTER NETWORKS',
#    'average_attainment': 66.79},
#   {'termNumber': '5',
#    'courseCode': '15CS53',
#    'section': 'B',
#    'facultyId': '380',
#    'courseName': 'DATABASE MANAGEMENT SYSTEM',
#    'average_attainment': 75.2},
#   {'termNumber': '5',
#    'courseCode': '15CS54',
#    'section': 'B',
#    'facultyId': '359',
#    'courseName': 'AUTOMATA THEORY AND COMPUTABILITY',
#    'average_attainment': 69.05},
#   {'termNumber': '5',
#    'courseCode': '15CS553',
#    'section': 'B',
#    'facultyId': '465',
#    'courseName': 'ADVANCED JAVA AND J2EE',
#    'average_attainment': 80.29},
#   {'termNumber': '5',
#    'courseCode': '15CS563',
#    'section': 'B',
#    'facultyId': '621',
#    'courseName': 'EMBEDDED COMPUTING SYSTEM',
#    'average_attainment': 65.73}],
#  'Co_Wise_Atainmnet_Val': [{'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS51',
#    'coNumber': 1,
#    'facultyId': '763',
#    'directAttainment': 84.77,
#    'indirectAttainment': 92.59,
#    'totalAttainment': 86.33},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS51',
#    'coNumber': 2,
#    'facultyId': '763',
#    'directAttainment': 84.38,
#    'indirectAttainment': 85.19,
#    'totalAttainment': 84.54},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS51',
#    'coNumber': 3,
#    'facultyId': '763',
#    'directAttainment': 84.82,
#    'indirectAttainment': 85.19,
#    'totalAttainment': 84.89},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS52',
#    'coNumber': 1,
#    'facultyId': '462',
#    'directAttainment': 79.97,
#    'indirectAttainment': 88.89,
#    'totalAttainment': 81.75},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS52',
#    'coNumber': 2,
#    'facultyId': '462',
#    'directAttainment': 82.56,
#    'indirectAttainment': 92.59,
#    'totalAttainment': 84.57},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS52',
#    'coNumber': 3,
#    'facultyId': '462',
#    'directAttainment': 70.64,
#    'indirectAttainment': 92.59,
#    'totalAttainment': 75.03},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS52',
#    'coNumber': 4,
#    'facultyId': '462',
#    'directAttainment': 70.8,
#    'indirectAttainment': 88.89,
#    'totalAttainment': 74.42},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS52',
#    'coNumber': 5,
#    'facultyId': '462',
#    'directAttainment': 48.64,
#    'indirectAttainment': 0.0,
#    'totalAttainment': 38.91},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS53',
#    'coNumber': 1,
#    'facultyId': '380',
#    'directAttainment': 73.01,
#    'indirectAttainment': 88.89,
#    'totalAttainment': 76.19},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS53',
#    'coNumber': 2,
#    'facultyId': '380',
#    'directAttainment': 65.11,
#    'indirectAttainment': 88.89,
#    'totalAttainment': 69.87},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS53',
#    'coNumber': 3,
#    'facultyId': '380',
#    'directAttainment': 71.62,
#    'indirectAttainment': 92.59,
#    'totalAttainment': 75.82},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS53',
#    'coNumber': 4,
#    'facultyId': '380',
#    'directAttainment': 72.5,
#    'indirectAttainment': 88.89,
#    'totalAttainment': 75.78},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS54',
#    'coNumber': 1,
#    'facultyId': '359',
#    'directAttainment': 78.19,
#    'indirectAttainment': 88.89,
#    'totalAttainment': 80.33},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS54',
#    'coNumber': 2,
#    'facultyId': '359',
#    'directAttainment': 77.83,
#    'indirectAttainment': 88.89,
#    'totalAttainment': 80.04},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS54',
#    'coNumber': 3,
#    'facultyId': '359',
#    'directAttainment': 71.23,
#    'indirectAttainment': 85.19,
#    'totalAttainment': 74.02},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS54',
#    'coNumber': 4,
#    'facultyId': '359',
#    'directAttainment': 74.48,
#    'indirectAttainment': 88.89,
#    'totalAttainment': 77.36},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS54',
#    'coNumber': 5,
#    'facultyId': '359',
#    'directAttainment': 73.36,
#    'indirectAttainment': 0.0,
#    'totalAttainment': 58.69},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS553',
#    'coNumber': 1,
#    'facultyId': '465',
#    'directAttainment': 77.06,
#    'indirectAttainment': 88.89,
#    'totalAttainment': 79.43},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS553',
#    'coNumber': 2,
#    'facultyId': '465',
#    'directAttainment': 77.67,
#    'indirectAttainment': 88.89,
#    'totalAttainment': 79.91},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS553',
#    'coNumber': 3,
#    'facultyId': '465',
#    'directAttainment': 68.7,
#    'indirectAttainment': 88.89,
#    'totalAttainment': 72.74},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS553',
#    'coNumber': 4,
#    'facultyId': '465',
#    'directAttainment': 68.96,
#    'indirectAttainment': 88.89,
#    'totalAttainment': 72.94},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS563',
#    'coNumber': 1,
#    'facultyId': '621',
#    'directAttainment': 78.34,
#    'indirectAttainment': 88.89,
#    'totalAttainment': 80.45},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS563',
#    'coNumber': 2,
#    'facultyId': '621',
#    'directAttainment': 79.26,
#    'indirectAttainment': 88.89,
#    'totalAttainment': 81.19},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS563',
#    'coNumber': 3,
#    'facultyId': '621',
#    'directAttainment': 68.99,
#    'indirectAttainment': 88.89,
#    'totalAttainment': 72.97},
#   {'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS563',
#    'coNumber': 4,
#    'facultyId': '621',
#    'directAttainment': 66.6,
#    'indirectAttainment': 88.89,
#    'totalAttainment': 71.06},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS51',
#    'coNumber': 1,
#    'facultyId': '763',
#    'directAttainment': 81.03,
#    'indirectAttainment': 100.0,
#    'totalAttainment': 84.82},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS51',
#    'coNumber': 2,
#    'facultyId': '763',
#    'directAttainment': 81.85,
#    'indirectAttainment': 100.0,
#    'totalAttainment': 85.48},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS51',
#    'coNumber': 3,
#    'facultyId': '763',
#    'directAttainment': 75.07,
#    'indirectAttainment': 100.0,
#    'totalAttainment': 80.06},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS52',
#    'coNumber': 1,
#    'facultyId': '462',
#    'directAttainment': 65.7,
#    'indirectAttainment': 100.0,
#    'totalAttainment': 72.56},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS52',
#    'coNumber': 2,
#    'facultyId': '462',
#    'directAttainment': 67.55,
#    'indirectAttainment': 100.0,
#    'totalAttainment': 74.04},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS52',
#    'coNumber': 3,
#    'facultyId': '462',
#    'directAttainment': 56.0,
#    'indirectAttainment': 100.0,
#    'totalAttainment': 64.8},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS52',
#    'coNumber': 4,
#    'facultyId': '462',
#    'directAttainment': 63.18,
#    'indirectAttainment': 100.0,
#    'totalAttainment': 70.54},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS52',
#    'coNumber': 5,
#    'facultyId': '462',
#    'directAttainment': 40.0,
#    'indirectAttainment': 100.0,
#    'totalAttainment': 52.0},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS53',
#    'coNumber': 1,
#    'facultyId': '380',
#    'directAttainment': 70.87,
#    'indirectAttainment': 100.0,
#    'totalAttainment': 76.7},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS53',
#    'coNumber': 2,
#    'facultyId': '380',
#    'directAttainment': 65.93,
#    'indirectAttainment': 100.0,
#    'totalAttainment': 72.75},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS53',
#    'coNumber': 3,
#    'facultyId': '380',
#    'directAttainment': 68.75,
#    'indirectAttainment': 100.0,
#    'totalAttainment': 75.0},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS53',
#    'coNumber': 4,
#    'facultyId': '380',
#    'directAttainment': 70.42,
#    'indirectAttainment': 100.0,
#    'totalAttainment': 76.34},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS54',
#    'coNumber': 1,
#    'facultyId': '359',
#    'directAttainment': 79.08,
#    'indirectAttainment': 100.0,
#    'totalAttainment': 83.26},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS54',
#    'coNumber': 2,
#    'facultyId': '359',
#    'directAttainment': 79.03,
#    'indirectAttainment': 100.0,
#    'totalAttainment': 83.22},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS54',
#    'coNumber': 3,
#    'facultyId': '359',
#    'directAttainment': 68.19,
#    'indirectAttainment': 100.0,
#    'totalAttainment': 74.55},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS54',
#    'coNumber': 4,
#    'facultyId': '359',
#    'directAttainment': 65.21,
#    'indirectAttainment': 0.0,
#    'totalAttainment': 52.17},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS54',
#    'coNumber': 5,
#    'facultyId': '359',
#    'directAttainment': 65.05,
#    'indirectAttainment': 0.0,
#    'totalAttainment': 52.04},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS553',
#    'coNumber': 1,
#    'facultyId': '465',
#    'directAttainment': 79.19,
#    'indirectAttainment': 100.0,
#    'totalAttainment': 83.35},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS553',
#    'coNumber': 2,
#    'facultyId': '465',
#    'directAttainment': 79.46,
#    'indirectAttainment': 100.0,
#    'totalAttainment': 83.57},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS553',
#    'coNumber': 3,
#    'facultyId': '465',
#    'directAttainment': 71.94,
#    'indirectAttainment': 100.0,
#    'totalAttainment': 77.55},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS553',
#    'coNumber': 4,
#    'facultyId': '465',
#    'directAttainment': 70.86,
#    'indirectAttainment': 100.0,
#    'totalAttainment': 76.69},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS563',
#    'coNumber': 1,
#    'facultyId': '621',
#    'directAttainment': 72.42,
#    'indirectAttainment': 100.0,
#    'totalAttainment': 77.94},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS563',
#    'coNumber': 2,
#    'facultyId': '621',
#    'directAttainment': 69.28,
#    'indirectAttainment': 100.0,
#    'totalAttainment': 75.42},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS563',
#    'coNumber': 3,
#    'facultyId': '621',
#    'directAttainment': 73.34,
#    'indirectAttainment': 0.0,
#    'totalAttainment': 58.67},
#   {'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS563',
#    'coNumber': 4,
#    'facultyId': '621',
#    'directAttainment': 63.63,
#    'indirectAttainment': 0.0,
#    'totalAttainment': 50.9}],
#  'Attainmnet_Details': [{'coNumber': 1,
#    'coTitle': 'Explain principles of application layer protocols',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS52',
#    'year': '2018-19',
#    'facultyId': '462',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [78.42, 81.06, 78.03],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [88.89],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 81.75,
#    'directAttainment': 79.97,
#    'indirectAttainment': 88.89},
#   {'coNumber': 2,
#    'coTitle': 'Recognize transport layer services and infer UDP and TCP protocols',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS52',
#    'year': '2018-19',
#    'facultyId': '462',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [87.08, 81.06, 78.03],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [92.59],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 84.57,
#    'directAttainment': 82.56,
#    'indirectAttainment': 92.59},
#   {'coNumber': 3,
#    'coTitle': 'Classify routers, IP and Routing Algorithms in network layer',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS52',
#    'year': '2018-19',
#    'facultyId': '462',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [73.33, 81.06, 0.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [92.59],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 75.03,
#    'directAttainment': 70.64,
#    'indirectAttainment': 92.59},
#   {'coNumber': 4,
#    'coTitle': 'Understand the Wireless and Mobile Networks covering IEEE 802.11 Standard',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS52',
#    'year': '2018-19',
#    'facultyId': '462',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [73.87, 81.06, 0.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [88.89],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 74.42,
#    'directAttainment': 70.8,
#    'indirectAttainment': 88.89},
#   {'coNumber': 5,
#    'coTitle': 'Describe Multimedia Networking and Network Management',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS52',
#    'year': '2018-19',
#    'facultyId': '462',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [0.0, 81.06, 0.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [0.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 38.91,
#    'directAttainment': 48.64,
#    'indirectAttainment': 0.0},
#   {'coNumber': 1,
#    'coTitle': 'Explain principles of application layer protocols',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS52',
#    'year': '2018-19',
#    'facultyId': '462',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [85.68, 66.67, 0.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [100.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 72.56,
#    'directAttainment': 65.7,
#    'indirectAttainment': 100.0},
#   {'coNumber': 2,
#    'coTitle': 'Recognize transport layer services and infer UDP and TCP protocols',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS52',
#    'year': '2018-19',
#    'facultyId': '462',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [91.83, 66.67, 0.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [100.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 74.04,
#    'directAttainment': 67.55,
#    'indirectAttainment': 100.0},
#   {'coNumber': 3,
#    'coTitle': 'Classify routers, IP and Routing Algorithms in network layer',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS52',
#    'year': '2018-19',
#    'facultyId': '462',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [53.33, 66.67, 0.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [100.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 64.8,
#    'directAttainment': 56.0,
#    'indirectAttainment': 100.0},
#   {'coNumber': 4,
#    'coTitle': 'Understand the Wireless and Mobile Networks covering IEEE 802.11 Standard',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS52',
#    'year': '2018-19',
#    'facultyId': '462',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [77.25, 66.67, 0.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [100.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 70.54,
#    'directAttainment': 63.18,
#    'indirectAttainment': 100.0},
#   {'coNumber': 5,
#    'coTitle': 'Describe Multimedia Networking and Network Management',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS52',
#    'year': '2018-19',
#    'facultyId': '462',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [0.0, 66.67, 0.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [100.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 52.0,
#    'directAttainment': 40.0,
#    'indirectAttainment': 100.0},
#   {'coNumber': 1,
#    'coTitle': 'Interpret the need for advanced Java concepts like enumerations and collections in developing modular and efficient programs',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS553',
#    'year': '2018-19',
#    'facultyId': '465',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [87.24, 70.45, 86.19],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [88.89],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 79.43,
#    'directAttainment': 77.06,
#    'indirectAttainment': 88.89},
#   {'coNumber': 2,
#    'coTitle': 'Demonstrate various String Handling Mechanism',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS553',
#    'year': '2018-19',
#    'facultyId': '465',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [85.66, 70.45, 96.97],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [88.89],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 79.91,
#    'directAttainment': 77.67,
#    'indirectAttainment': 88.89},
#   {'coNumber': 3,
#    'coTitle': 'Describe how servlets fit into Java-based web application architecture',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS553',
#    'year': '2018-19',
#    'facultyId': '465',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [88.09, 70.45, 0.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [88.89],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 72.74,
#    'directAttainment': 68.7,
#    'indirectAttainment': 88.89},
#   {'coNumber': 4,
#    'coTitle': 'Illustrate database access and details for managing information using the JDBC API',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS553',
#    'year': '2018-19',
#    'facultyId': '465',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [88.95, 70.45, 0.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [88.89],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 72.94,
#    'directAttainment': 68.96,
#    'indirectAttainment': 88.89},
#   {'coNumber': 1,
#    'coTitle': 'Interpret the need for advanced Java concepts like enumerations and collections in developing modular and efficient programs',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS553',
#    'year': '2018-19',
#    'facultyId': '465',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [90.53, 71.43, 91.73],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [100.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 83.35,
#    'directAttainment': 79.19,
#    'indirectAttainment': 100.0},
#   {'coNumber': 2,
#    'coTitle': 'Demonstrate various String Handling Mechanism',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS553',
#    'year': '2018-19',
#    'facultyId': '465',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [89.6, 71.43, 97.22],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [100.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 83.57,
#    'directAttainment': 79.46,
#    'indirectAttainment': 100.0},
#   {'coNumber': 3,
#    'coTitle': 'Describe how servlets fit into Java-based web application architecture',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS553',
#    'year': '2018-19',
#    'facultyId': '465',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [96.94, 71.43, 0.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [100.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 77.55,
#    'directAttainment': 71.94,
#    'indirectAttainment': 100.0},
#   {'coNumber': 4,
#    'coTitle': 'Illustrate database access and details for managing information using the JDBC API',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS553',
#    'year': '2018-19',
#    'facultyId': '465',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [93.33, 71.43, 0.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [100.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 76.69,
#    'directAttainment': 70.86,
#    'indirectAttainment': 100.0},
#   {'coNumber': 1,
#    'coTitle': 'Acquire fundamental understanding of the core concepts in automata theory\nand Theory of Computation',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS54',
#    'year': '2018-19',
#    'facultyId': '359',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [92.4, 69.7, 86.51],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [88.89],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 80.33,
#    'directAttainment': 78.19,
#    'indirectAttainment': 88.89},
#   {'coNumber': 2,
#    'coTitle': 'Learn how to translate between different models of Computation (e.g.,\nDeterministic and Non-deterministic and Software models)',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS54',
#    'year': '2018-19',
#    'facultyId': '359',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [92.42, 69.7, 82.8],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [88.89],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 80.04,
#    'directAttainment': 77.83,
#    'indirectAttainment': 88.89},
#   {'coNumber': 3,
#    'coTitle': 'Design Grammars and Automata (recognizers) for different language classes\nand become knowledgeable about restricted models of Computation\n(Regular, Context Free) and their relative powers',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS54',
#    'year': '2018-19',
#    'facultyId': '359',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [71.68, 69.7, 79.09],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [85.19],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 74.02,
#    'directAttainment': 71.23,
#    'indirectAttainment': 85.19},
#   {'coNumber': 4,
#    'coTitle': 'Develop skills in formal reasoning and reduction of a problem to a formal\nmodel, with an emphasis on semantic precision and conciseness',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS54',
#    'year': '2018-19',
#    'facultyId': '359',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [82.52, 69.7, 79.09],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [88.89],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 77.36,
#    'directAttainment': 74.48,
#    'indirectAttainment': 88.89},
#   {'coNumber': 5,
#    'coTitle': 'Classify a problem with respect to different models of Computation',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS54',
#    'year': '2018-19',
#    'facultyId': '359',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [71.79, 69.7, 100.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [0.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 58.69,
#    'directAttainment': 73.36,
#    'indirectAttainment': 0.0},
#   {'coNumber': 1,
#    'coTitle': 'Acquire fundamental understanding of the core concepts in automata theory\nand Theory of Computation',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS54',
#    'year': '2018-19',
#    'facultyId': '359',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [93.81, 69.52, 92.22],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [100.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 83.26,
#    'directAttainment': 79.08,
#    'indirectAttainment': 100.0},
#   {'coNumber': 2,
#    'coTitle': 'Learn how to translate between different models of Computation (e.g.,\nDeterministic and Non-deterministic and Software models)',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS54',
#    'year': '2018-19',
#    'facultyId': '359',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [93.64, 69.52, 92.22],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [100.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 83.22,
#    'directAttainment': 79.03,
#    'indirectAttainment': 100.0},
#   {'coNumber': 3,
#    'coTitle': 'Design Grammars and Automata (recognizers) for different language classes\nand become knowledgeable about restricted models of Computation\n(Regular, Context Free) and their relative powers',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS54',
#    'year': '2018-19',
#    'facultyId': '359',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [88.26, 69.52, 0.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [100.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 74.55,
#    'directAttainment': 68.19,
#    'indirectAttainment': 100.0},
#   {'coNumber': 4,
#    'coTitle': 'Develop skills in formal reasoning and reduction of a problem to a formal\nmodel, with an emphasis on semantic precision and conciseness',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS54',
#    'year': '2018-19',
#    'facultyId': '359',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [78.33, 69.52, 0.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [0.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 52.17,
#    'directAttainment': 65.21,
#    'indirectAttainment': 0.0},
#   {'coNumber': 5,
#    'coTitle': 'Classify a problem with respect to different models of Computation',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS54',
#    'year': '2018-19',
#    'facultyId': '359',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [77.78, 69.52, 0.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [0.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 52.04,
#    'directAttainment': 65.05,
#    'indirectAttainment': 0.0},
#   {'coNumber': 1,
#    'coTitle': 'Distinguish the characteristics of embedded computer systems',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS563',
#    'year': '2018-19',
#    'facultyId': '621',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [86.99, 75.76, 67.88],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [88.89],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 80.45,
#    'directAttainment': 78.34,
#    'indirectAttainment': 88.89},
#   {'coNumber': 2,
#    'coTitle': 'Examine the various vulnerabilities of embedded computer systems',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS563',
#    'year': '2018-19',
#    'facultyId': '621',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [89.61, 75.76, 69.24],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [88.89],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 81.19,
#    'directAttainment': 79.26,
#    'indirectAttainment': 88.89},
#   {'coNumber': 3,
#    'coTitle': 'design and develop modules using RTOS',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS563',
#    'year': '2018-19',
#    'facultyId': '621',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [55.36, 75.76, 69.24],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [88.89],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 72.97,
#    'directAttainment': 68.99,
#    'indirectAttainment': 88.89},
#   {'coNumber': 4,
#    'coTitle': 'Implement RPC, threads and tasks',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS563',
#    'year': '2018-19',
#    'facultyId': '621',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [70.5, 75.76, 0.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [88.89],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 71.06,
#    'directAttainment': 66.6,
#    'indirectAttainment': 88.89},
#   {'coNumber': 1,
#    'coTitle': 'Distinguish the characteristics of embedded computer systems',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS563',
#    'year': '2018-19',
#    'facultyId': '621',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [81.98, 69.52, 61.11],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [100.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 77.94,
#    'directAttainment': 72.42,
#    'indirectAttainment': 100.0},
#   {'coNumber': 2,
#    'coTitle': 'Examine the various vulnerabilities of embedded computer systems',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS563',
#    'year': '2018-19',
#    'facultyId': '621',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [64.1, 69.52, 83.33],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [100.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 75.42,
#    'directAttainment': 69.28,
#    'indirectAttainment': 100.0},
#   {'coNumber': 3,
#    'coTitle': 'design and develop modules using RTOS',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS563',
#    'year': '2018-19',
#    'facultyId': '621',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [77.65, 69.52, 83.33],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [0.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 58.67,
#    'directAttainment': 73.34,
#    'indirectAttainment': 0.0},
#   {'coNumber': 4,
#    'coTitle': 'implement RPC,threads and tasks',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS563',
#    'year': '2018-19',
#    'facultyId': '621',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [73.05, 69.52, 0.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [0.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 50.9,
#    'directAttainment': 63.63,
#    'indirectAttainment': 0.0},
#   {'coNumber': 1,
#    'coTitle': 'Identify, analyze and define database objects, enforce integrity constraints on a\ndatabase using RDBMS',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS53',
#    'year': '2018-19',
#    'facultyId': '380',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [96.23, 53.33, 100.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [100.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 76.7,
#    'directAttainment': 70.87,
#    'indirectAttainment': 100.0},
#   {'coNumber': 2,
#    'coTitle': 'Use Structured Query Language (SQL) for database manipulation',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS53',
#    'year': '2018-19',
#    'facultyId': '380',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [84.77, 53.33, 85.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [100.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 72.75,
#    'directAttainment': 65.93,
#    'indirectAttainment': 100.0},
#   {'coNumber': 3,
#    'coTitle': 'Design and build simple database systems',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS53',
#    'year': '2018-19',
#    'facultyId': '380',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [89.18, 53.33, 100.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [100.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 75.0,
#    'directAttainment': 68.75,
#    'indirectAttainment': 100.0},
#   {'coNumber': 4,
#    'coTitle': 'Design and build GUI application to interact with databases',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS53',
#    'year': '2018-19',
#    'facultyId': '380',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [94.74, 53.33, 100.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [100.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 76.34,
#    'directAttainment': 70.42,
#    'indirectAttainment': 100.0},
#   {'coNumber': 1,
#    'coTitle': 'Identify, analyze and define database objects, enforce integrity constraints on a\ndatabase using RDBMS',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS53',
#    'year': '2018-19',
#    'facultyId': '380',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [93.37, 58.33, 100.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [88.89],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 76.19,
#    'directAttainment': 73.01,
#    'indirectAttainment': 88.89},
#   {'coNumber': 2,
#    'coTitle': 'Use Structured Query Language (SQL) for database manipulation',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS53',
#    'year': '2018-19',
#    'facultyId': '380',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [77.04, 58.33, 70.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [88.89],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 69.87,
#    'directAttainment': 65.11,
#    'indirectAttainment': 88.89},
#   {'coNumber': 3,
#    'coTitle': 'Design and build simple database systems',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS53',
#    'year': '2018-19',
#    'facultyId': '380',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [88.74, 58.33, 100.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [92.59],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 75.82,
#    'directAttainment': 71.62,
#    'indirectAttainment': 92.59},
#   {'coNumber': 4,
#    'coTitle': 'Design and build GUI application to interact with databases',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS53',
#    'year': '2018-19',
#    'facultyId': '380',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [91.67, 58.33, 100.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [88.89],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 75.78,
#    'directAttainment': 72.5,
#    'indirectAttainment': 88.89},
#   {'coNumber': 1,
#    'coTitle': 'Define management, organization, entrepreneur, planning, staffing, ERP and outline\ntheir importance in entrepreneurship',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS51',
#    'year': '2018-19',
#    'facultyId': '763',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [90.89, 79.55, 97.73],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [92.59],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 86.33,
#    'directAttainment': 84.77,
#    'indirectAttainment': 92.59},
#   {'coNumber': 2,
#    'coTitle': 'Utilize the resources available effectively through ERP',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS51',
#    'year': '2018-19',
#    'facultyId': '763',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [91.55, 79.55, 91.82],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [85.19],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 84.54,
#    'directAttainment': 84.38,
#    'indirectAttainment': 85.19},
#   {'coNumber': 3,
#    'coTitle': 'Make us of IPRs and institutional support in entrepreneurship',
#    'termNumber': '5',
#    'section': 'A',
#    'courseCode': '15CS51',
#    'year': '2018-19',
#    'facultyId': '763',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [91.07, 79.55, 97.73],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [85.19],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 84.89,
#    'directAttainment': 84.82,
#    'indirectAttainment': 85.19},
#   {'coNumber': 1,
#    'coTitle': 'Define management, organization, entrepreneur, planning, staffing, ERP and outline\ntheir importance in entrepreneurship',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS51',
#    'year': '2018-19',
#    'facultyId': '763',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [88.2, 74.29, 100.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [100.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 84.82,
#    'directAttainment': 81.03,
#    'indirectAttainment': 100.0},
#   {'coNumber': 2,
#    'coTitle': 'Utilize the resources available effectively through ERP',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS51',
#    'year': '2018-19',
#    'facultyId': '763',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [93.51, 74.29, 92.22],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [100.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 85.48,
#    'directAttainment': 81.85,
#    'indirectAttainment': 100.0},
#   {'coNumber': 3,
#    'coTitle': 'Make us of IPRs and institutional support in entrepreneurship',
#    'termNumber': '5',
#    'section': 'B',
#    'courseCode': '15CS51',
#    'year': '2018-19',
#    'facultyId': '763',
#    'dir_methodName': ['IA', 'UE', 'Other Assessment'],
#    'dir_methodDescription': ['Internal Assessment', ''],
#    'dir_attainment': [68.34, 74.29, 100.0],
#    'dir_attainmentPercentage': [0.0, 0.0, 0.0],
#    'indir_attainment': [100.0],
#    'indir_attainmentPercentage': [0.0],
#    'indir_methodName': ['Feedback'],
#    'indir_methodDescription': ['CES'],
#    'totalAttainment': 80.06,
#    'directAttainment': 75.07,
#    'indirectAttainment': 100.0}]}
